# %% [markdown]
# # Create xyz and CIF files of Johnson NPs of different sizes and forms from a dataset of compounds (CIF dataset)

# %% [markdown]
# #### Two classes : one for the fcc trigonal bipyramid and one for pentagonal bipyramids (decahedron) and elongated bipyramids

# %% [markdown]
# ## Imports

# %%
import os
import sys
import tkinter

print(os.getcwd())
cwd0 = './styles/'
sys.path.append(cwd0)
from pathlib import Path
import numpy as np
import visualID as vID
from visualID import  fg, hl, bg

from pyNanoMatBuilder import johnsonNPs as jNP
from pyNanoMatBuilder import utils as pyNMBu
from pyNanoMatBuilder import data
import importlib

from ase import io
from ase.atoms import Atoms
from ase.geometry import cellpar_to_cell
from ase.spacegroup import get_spacegroup
from ase.io import read
from ase.io import write
from ase.visualize import view

from debyecalculator import DebyeCalculator
import pyNanoMatBuilder.utilsDC as pyNMBuDC
# Out:
# /home/sara/pyNanoMatBuilder

# %% [markdown]
# ## 1. Class for fcc trigonal bipyramids

# %% [markdown]
# #### NB: the Johnson class is instantiated by defining a compound and its interatomic distance. The function FindInterAtomicDist, which is defined in utils, calculates the interatomic distance by extracting the cell paratemers and uses well known formulas for fcc, bcc and hcp. Thus, compounds with unknown interatomic distances are not used to create Platonic NPs.

# %% [markdown]
# <span style="color:#FF0000"> Problem : not possible to create the forms for multiple elements like TiO2 or NaCl

# %% [markdown]
# ### Definition of the 'Johnson_fcctbp_Files' class

# %%
class Johnson_fcctbp_Files :
    """
    A class for generating XYZ and CIF files of fcc trigonal bipyramid (fcctbp) Johnson nanoparticles (NPs) 
    from a dataset of compounds (CIF dataset). This process enables the creation 
    of a well-structured database optimized for machine learning applications, 
    ensuring consistency in format and data representation.
    """
    def __init__(self, path, cif_data,sizes,max_size: float=50,noOutput:bool = True):
        """
        Initialize the class with CIF data and sizes.
            Args:
        path (str) : Path that will contain the created xyz files
        cif data (DataFrame):  DataFrame containing CIF files of different compounds
        sizes (array-like): Array of the number of bonds per edges, ex: [2,3,4]
        max_size (float, optional) : Maximal size for the NPs, equals to the diameter of the circumscribed sphere, equals 50 nm by default.
        noOutput (bool): If False, details of the files are printed.
            Methods:
        create_johnson_fcctbp(noOutput, path): Generates fcctbp Johnson nanoparticlesand saves their files.
        """
        self.cif_data = cif_data  # DataFrame containing CIF
        self.loaded_cifs = {}  # Dictionary to store loaded CIF files
        self.sizes= sizes # List of sizes 

        
        self.create_johnson_fcctbp(noOutput,max_size,path) # Call method to generate Johnson nanoparticles
  
    def create_johnson_fcctbp(self,noOutput,max_size,path):
        """
        Genenrate platonic NPs and their files from cif data.
        Args:
            noOutput (bool): If False, prints details about the process.
            path (str): Path where xyz/cif files will be created.
        Note:
        - The nanoparticles are created using classes of the module 'jNP' 
        and the class 'fcctbp'
        """
    
        
        for cif_name, cif_file in self.cif_data['cif file'].items():
            
            # Load cif informations
            element=cif_name.split()[0] # Extract chemical element from CIF name
            
            if not (element=='TiO2' or element=='NaCl'): # Skip TiO2 and NaCl since they are not processed
                self.cif_name=cif_name
                
                # Extract the structure name for the name of the files, for example 'Rutile' or 'Anatase' or 'Alpha'
                if len(self.cif_name.split())==2 : 
                    structure=self.cif_name.split()[1]
                else : 
                    structure=None
                
                if not noOutput :
                    print(f'\n\033[1m{cif_name.center(50)}\033[0m\n')
                cif_info = pyNMBu.load_cif(self,cif_file,noOutput)
                    
                # Determine forms based on crystal type
                if self.crystal_type=='fcc' :
                    dist= pyNMBu.FindInterAtomicDist(self)# Extract the interatomic distance
                    index=0 
                    if not noOutput :
                        print(f" {bg.LIGHTGREENB} xyz/cif files can be created for {self.cif_name} of Bravais lattice={self.crystal_type}. \033[0m ")
   
                    # Create instances for each form and size
                    for i in self.sizes :
                        index += 1 
                        if not noOutput :
                            print(f'Number of bonds is {i}')
                        TestNP =jNP.fcctbp(
                            element=element,
                            Rnn=dist,
                            nLayerTd=i,
                            postAnalyzis=True,
                            aseView=False,
                            thresholdCoreSurface=1,
                            skipSymmetryAnalyzis=True,
                            noOutput= True
                        )

                        circumsphere_diameter=TestNP.radiusCircumscribedSphere*2*0.1 # Setting a maximal size of NPs : circumscribed sphere diameter
                        if circumsphere_diameter<max_size :
                            if not noOutput :
                                print(f'{bg.LIGHTBLUEB}Circumscribed sphere diameter ={circumsphere_diameter}\033[0m')
                            pyNMBu.writexyz_generalized_johnson(self,structure,path,TestNP,index,noOutput) 
                        else :
                            break
                

                else : 
                    if not noOutput :
                        print(f" {bg.LIGHTREDB} xyz/cif files can't be created for {self.cif_name} because the crystal type isn't fcc.\033[0m  ")   
                    pass

          
            else :
                pass

# %%
Johnson_fcctbp_Files?
# Out:
# Init signature:
# Johnson_fcctbp_Files(
#     path,
#     cif_data,
#     sizes,
#     max_size: float = 50,
#     noOutput: bool = True,
# )
# Docstring:
# A class for generating XYZ and CIF files of fcc trigonal bipyramid (fcctbp) Johnson nanoparticles (NPs)
# from a dataset of compounds (CIF dataset). This process enables the creation
# of a well-structured database optimized for machine learning applications,
# ensuring consistency in format and data representation.
# Init docstring:
# Initialize the class with CIF data and sizes.
#     Args:
# path (str) : Path that will contain the created xyz files
# cif data (DataFrame):  DataFrame containing CIF files of different compounds
# sizes (array-like): Array of the number of bonds per edges, ex: [2,3,4]
# max_size (float, optional) : Maximal size for the NPs, equals to the diameter of the circumscribed sphere, equals 50 nm by default.
# noOutput (bool): If False, details of the files are printed.
#     Methods:
# create_johnson_fcctbp(noOutput, path): Generates fcctbp Johnson nanoparticlesand saves their files.
# Type:           type
# Subclasses:

# %% [markdown]
# ### Example of use of the  Johnson_fcctbp_Files class

# %% [markdown]
# ##### Create all the possible forms from a dataset of CIF files

# %% [markdown]
# If noOutput=False :
#  - <span style="color:#008000"> in green : the allowed shapes created (fcc) </span>
#  - <span style="color:#FF0000">in red : the shapes that are not created (not fcc)</span>

# %%
t = pyNMBu.timer()
t.chrono_start()

# Path where the files are created
path='database_1_5nm/fcctbp_johnson_1_5nm'

# Sizes of the NPs
sizes=np.arange(1,30,1) # Control the sizes by the number of bonds per edges : here 1 to 25 bonds (step of 1)

# Possiblity to define a maximal size: max_size (a circumsphere diameter). If max_size isn't defined, the NPs will have the maximum number of bonds defined, here 25.
class_test=Johnson_fcctbp_Files(path,cif_data=data.pyNMBcif.CIFdf,sizes=sizes,max_size=5,noOutput= False) # Ex: the maximal size is a circumsphere diameter of 5 nm.



print(t.chrono_stop(hdelay=True))
# Out:
#                       Fe bcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod5000217-Fe_bcc.cif
#   xyz/cif files can't be created for Fe bcc because the crystal type isn't fcc.
#
#                      Mn alpha
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9011068-Mn_alpha.cif
#   xyz/cif files can't be created for Mn alpha because the crystal type isn't fcc.
#
#                      Mn beta
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod1539039-Mn_beta.cif
#   xyz/cif files can't be created for Mn beta because the crystal type isn't fcc.
#
#                       Co hcp
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008492-Co_hcp.cif
#   xyz/cif files can't be created for Co hcp because the crystal type isn't fcc.
#
#                       Co fcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008466-Co_fcc.cif
#   xyz/cif files can be created for Co fcc of Bravais lattice=fcc.
# Number of bonds is 1
# Circumscribed sphere diameter =0.40968775101695853
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000001_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000001_0000000.cif
# Number of bonds is 2
# Circumscribed sphere diameter =0.8193755020339171
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000002_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000002_0000000.cif
# Number of bonds is 3
# Circumscribed sphere diameter =1.2290632530508756
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000003_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000003_0000000.cif
# Number of bonds is 4
# Circumscribed sphere diameter =1.6387510040678341
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000004_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000004_0000000.cif
# Number of bonds is 5
# Circumscribed sphere diameter =2.0484387550847933
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000005_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000005_0000000.cif
# Number of bonds is 6
# Circumscribed sphere diameter =2.458126506101751
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000006_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000006_0000000.cif
# Number of bonds is 7
# Circumscribed sphere diameter =2.8678142571187095
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000007_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000007_0000000.cif
# Number of bonds is 8
# Circumscribed sphere diameter =3.2775020081356683
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000008_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000008_0000000.cif
# Number of bonds is 9
# Circumscribed sphere diameter =3.6871897591526257
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000009_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000009_0000000.cif
# Number of bonds is 10
# /home/sara/Python3/Debye_calc/lib/python3.11/site-packages/ase/io/cif.py:408: UserWarning: crystal system 'cubic' is not interpreted for space group Spacegroup(229, setting=1). This may result in wrong setting!
#   warnings.warn(
# /home/sara/pyNanoMatBuilder/pyNanoMatBuilder/platonicNPs.py:918: RuntimeWarning: invalid value encountered in scalar divide
#   return self.heightOfPyramid()/(self.nLayer-1)
# Circumscribed sphere diameter =4.096877510169587
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000010_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000010_0000000.cif
# Number of bonds is 11
# Circumscribed sphere diameter =4.506565261186544
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000011_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000011_0000000.cif
# Number of bonds is 12
# Circumscribed sphere diameter =4.916253012203502
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000012_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Co_fcc_fcctbp_0000012_0000000.cif
# Number of bonds is 13
#
#                     Co epsilon
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9012884-Co_epsilon.cif
#   xyz/cif files can't be created for Co epsilon because the crystal type isn't fcc.
#
#                       Ru hcp
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008513-Ru_hcp.cif
#   xyz/cif files can't be created for Ru hcp because the crystal type isn't fcc.
#
#                       Pt fcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9012957-Pt_fcc.cif
#   xyz/cif files can be created for Pt fcc of Bravais lattice=fcc.
# Number of bonds is 1
# Circumscribed sphere diameter =0.45215763681854737
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000001_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000001_0000000.cif
# Number of bonds is 2
# Circumscribed sphere diameter =0.9043152736370947
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000002_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000002_0000000.cif
# Number of bonds is 3
# Circumscribed sphere diameter =1.3564729104556421
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000003_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000003_0000000.cif
# Number of bonds is 4
# Circumscribed sphere diameter =1.8086305472741895
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000004_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000004_0000000.cif
# Number of bonds is 5
# Circumscribed sphere diameter =2.2607881840927364
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000005_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000005_0000000.cif
# Number of bonds is 6
# Circumscribed sphere diameter =2.7129458209112842
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000006_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000006_0000000.cif
# Number of bonds is 7
# Circumscribed sphere diameter =3.165103457729831
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000007_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000007_0000000.cif
# Number of bonds is 8
# Circumscribed sphere diameter =3.617261094548379
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000008_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000008_0000000.cif
# Number of bonds is 9
# Circumscribed sphere diameter =4.069418731366926
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000009_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000009_0000000.cif
# Number of bonds is 10
# Circumscribed sphere diameter =4.521576368185473
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000010_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000010_0000000.cif
# Number of bonds is 11
# Circumscribed sphere diameter =4.973734005004021
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000011_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Pt_fcc_fcctbp_0000011_0000000.cif
# Number of bonds is 12
#
#                       Au fcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008463-Au_fcc.cif
#   xyz/cif files can be created for Au fcc of Bravais lattice=fcc.
# Number of bonds is 1
# Circumscribed sphere diameter =0.4709157470645182
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000001_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000001_0000000.cif
# Number of bonds is 2
# Circumscribed sphere diameter =0.9418314941290364
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000002_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000002_0000000.cif
# Number of bonds is 3
# Circumscribed sphere diameter =1.4127472411935549
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000003_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000003_0000000.cif
# Number of bonds is 4
# Circumscribed sphere diameter =1.8836629882580729
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000004_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000004_0000000.cif
# Number of bonds is 5
# Circumscribed sphere diameter =2.3545787353225918
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000005_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000005_0000000.cif
# Number of bonds is 6
# Circumscribed sphere diameter =2.8254944823871098
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000006_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000006_0000000.cif
# Number of bonds is 7
# Circumscribed sphere diameter =3.296410229451629
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000007_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000007_0000000.cif
# Number of bonds is 8
# Circumscribed sphere diameter =3.7673259765161458
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000008_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000008_0000000.cif
# Number of bonds is 9
# Circumscribed sphere diameter =4.238241723580664
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000009_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000009_0000000.cif
# Number of bonds is 10
# Circumscribed sphere diameter =4.7091574706451835
#   xyz file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000010_0000000.xyz
#   cif file created:database_1_5nm/fcctbp_johnson_1_5nm/Au_fcc_fcctbp_0000010_0000000.cif
# Number of bonds is 11
#
#                      Fe beta
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod1539039-Fe_beta.cif
#   xyz/cif files can't be created for Fe beta because the crystal type isn't fcc.
# 00:00:00 032ms

# %% [markdown]
# ## Class for pentagonal bipyramids (decahedron) and elongated bipyramids

# %% [markdown]
# ### Definition of the 'Johnson_epbpyM_Files' class

# %%
class Johnson_epbpyM_Files:### Pentagonal bipyramids (decahedron) and elongated bipyramids
    """
    A class for generating XYZ and CIF files of pentagonal bipyramids (decahedron) and elongated bipyramids Johnson nanoparticles (NPs) 
    from a dataset of compounds (CIF dataset). This process enables the creation 
    of a well-structured database optimized for machine learning applications, 
    ensuring consistency in format and data representation.
    """
    def __init__(self, path, cif_data,sizes,max_size: float=50,noOutput:bool = True):
        """
        Initialize the class with CIF data and sizes.
            Args:
        path (str) : Path that will contain the created xyz files
        cif data (DataFrame):  DataFrame containing CIF files of different compounds
        sizes (array-like): Array of the number of bonds per edges, ex: [2,3,4]
        max_size (float, optional) : Maximal size for the NPs, equals to the diameter of the circumscribed sphere, equals 50 nm by default.
        noOutput (bool): If False, details of the files are printed.
            Methods:
        create_johnson_epbpyM(noOutput, path): Generates fcctbp Johnson nanoparticlesand saves their files.
        """
        self.cif_data = cif_data  # DataFrame containing CIF
        self.loaded_cifs = {}  # Dictionary to store loaded CIF files
        self.sizes=sizes # [sizeP,sizeE,Marks]
        self.sizeP= np.unique(sizes [:, 0])# list of the number of bonds on the edge of the pentagonal cross section
        self.sizeE= np.unique(sizes [:, 1])# list of the number of bonds on the edge of the elongated part
        self.Marks= np.unique(sizes [:, 2]) # list of numbers of truncated atoms

        
        self.create_johnson_epbpyM(noOutput,sizes,max_size,path) # Call method to generate Johnson nanoparticles
  
    def create_johnson_epbpyM(self,noOutput,sizes,max_size,path):
        """
        Genenrate platonic NPs and their files from cif data.
        Args:
            noOutput (bool): If False, prints details about the process.
            path (str): Path where xyz/cif files will be created.
        Note:
        - The nanoparticles are created using classes of the module 'jNP' 
        and the class 'fcctbp'
        """
    
        if not noOutput:
            print(f' The sizes are given using the following format : [number of bonds per edge of pentagonal cross section, number of bonds per edge of elongated part, number of truncated atoms]')
        for cif_name, cif_file in self.cif_data['cif file'].items():
            
            # Load cif informations
            element=cif_name.split()[0] # Extract chemical element from CIF name
            
            if not (element=='TiO2' or element=='NaCl'): # Skip TiO2 and NaCl since they are not processed
                self.cif_name=cif_name
                
                # Extract the structure name for the name of the files, for example 'Rutile' or 'Anatase' or 'Alpha'
                if len(self.cif_name.split())==2 : 
                    structure=self.cif_name.split()[1]
                else : 
                    structure=None
                
                if not noOutput :
                    print(f'\n\033[1m{cif_name.center(50)}\033[0m\n')
                cif_info = pyNMBu.load_cif(self,cif_file,noOutput)
                    
                # Determine forms based on crystal type
                if self.crystal_type=='fcc' :
                    dist= pyNMBu.FindInterAtomicDist(self)# Extract the interatomic distance
                elif self.crystal_type=='bcc':
                    dist= pyNMBu.FindInterAtomicDist(self) # Extract the interatomic distance
                elif self.crystal_type=='hcp':
                    dist= pyNMBu.FindInterAtomicDist(self) # Extract the interatomic distance
                else : 
                    dist=None
                    if not noOutput :
                        print(f" {bg.LIGHTREDB} xyz/cif files can't be created for {self.cif_name} because the interatomic distance is unknown.\033[0m  ")   
                        
                if not dist==None:
 
                    index=0 
                    if not noOutput :
                        print(f" {bg.LIGHTGREENB} xyz/cif files can be created for {self.cif_name} of Bravais lattice={self.crystal_type}. \033[0m ")
   
                    # Create instances for each form and size
                    # for i in self.sizeP :
                    #     for y in self.sizeE:
                    #         for z in self.Marks:

                    for i, y, z in sizes:
                        index += 1 
                        if not noOutput :
                            print(f'{bg.LIGHTBLUEB} [{i},{y},{z}]  ')
                        TestNP =jNP.epbpyM(
                            element=element,
                            Rnn=dist,
                            sizeP=i,
                            sizeE=y,
                            Marks=z,
                            postAnalyzis=True,
                            aseView=False,
                            thresholdCoreSurface=1,
                            skipSymmetryAnalyzis=True,
                            noOutput= True
                        )
           
                        circumsphere_diameter=TestNP.radiusCircumscribedSphere*2*0.1 # Setting a maximal size of NPs : circumscribed sphere diameter
                        if circumsphere_diameter<max_size :
                            if not noOutput :
                                print(f'{bg.LIGHTBLUEB}Circumscribed sphere diameter ={circumsphere_diameter}\033[0m')
                            pyNMBu.writexyz_generalized_johnson(self,structure,path,TestNP,index,noOutput) 
                        else :
                            break
                

          
            else :
                pass

# %% [markdown]
# ### Example of use of the Johnson_epbpyM_Files class

# %% [markdown]
# An example of possible combinations of sizes (size of the pentagonal cap, size of the elongated part and Marks=truncated atoms per vertices).

# %%
import numpy as np
from itertools import product

sizeP = np.arange(3, 7, 1)  # Ex: [3, 4, 5, 6]
sizeE = np.arange(3, 5, 1)  # Ex: [3, 4, ..., 14]
Marks = np.arange(0, 4, 1)  # Ex: [0, 1, 2, 3]

# Générer toutes les combinaisons possibles
valid_combinations = [(p, e, m) for p, e, m in product(sizeP, sizeE, Marks) if m <= (p-1) // 2]

# Convertir en tableau numpy si nécessaire
valid_combinations = np.array(valid_combinations)

print(valid_combinations)
# Out:
# [[3 3 0]
#  [3 3 1]
#  [3 4 0]
#  [3 4 1]
#  [4 3 0]
#  [4 3 1]
#  [4 4 0]
#  [4 4 1]
#  [5 3 0]
#  [5 3 1]
#  [5 3 2]
#  [5 4 0]
#  [5 4 1]
#  [5 4 2]
#  [6 3 0]
#  [6 3 1]
#  [6 3 2]
#  [6 4 0]
#  [6 4 1]
#  [6 4 2]]

# %%
t = pyNMBu.timer()
t.chrono_start()

# Path where the files are created
path='database_1_5nm/epbpyM_johnson_1_5nm'

# Possiblity to define a maximal size: max_size (a circumsphere diameter). If max_size isn't defined, the NPs will have the maximum number of bonds defined, here 25.
class_test=Johnson_epbpyM_Files(path,cif_data=data.pyNMBcif.CIFdf,sizes=valid_combinations,max_size=5,noOutput= False) # Ex: the maximal size is a circumsphere diameter of 5 nm.



print(t.chrono_stop(hdelay=True))
# Out:
#  The sizes are given using the following format : [number of bonds per edge of pentagonal cross section, number of bonds per edge of elongated part, number of truncated atoms]
#
#                       Fe bcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod5000217-Fe_bcc.cif
#   xyz/cif files can be created for Fe bcc of Bravais lattice=bcc.
#  [3,3,0]
# Circumscribed sphere diameter =1.563014668022719
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000001_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000001_0000000.cif
#  [3,3,1]
# Circumscribed sphere diameter =1.563014668022719
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000002_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000002_0000000.cif
#  [3,4,0]
# Circumscribed sphere diameter =1.8235171126931722
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000003_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000003_0000000.cif
#  [3,4,1]
# Circumscribed sphere diameter =1.8235171126931722
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000004_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000004_0000000.cif
#  [4,3,0]
# Circumscribed sphere diameter =1.8583256230932783
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000005_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000005_0000000.cif
#  [4,3,1]
# Circumscribed sphere diameter =1.8235171126931722
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000006_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000006_0000000.cif
# /home/sara/Python3/Debye_calc/lib/python3.11/site-packages/ase/io/cif.py:408: UserWarning: crystal system 'cubic' is not interpreted for space group Spacegroup(229, setting=1). This may result in wrong setting!
#   warnings.warn(
#  [4,4,0]
# Circumscribed sphere diameter =2.084019557363625
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000007_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000007_0000000.cif
#  [4,4,1]
# Circumscribed sphere diameter =2.084019557363625
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000008_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000008_0000000.cif
#  [5,3,0]
# Circumscribed sphere diameter =2.247742890352782
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000009_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000009_0000000.cif
#  [5,3,1]
# Circumscribed sphere diameter =2.084019557363625
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000010_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000010_0000000.cif
#  [5,3,2]
# Circumscribed sphere diameter =2.084019557363625
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000011_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000011_0000000.cif
#  [5,4,0]
# Circumscribed sphere diameter =2.35103780634988
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000012_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000012_0000000.cif
#  [5,4,1]
# Circumscribed sphere diameter =2.3445220020340782
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000013_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000013_0000000.cif
#  [5,4,2]
# Circumscribed sphere diameter =2.3445220020340782
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000014_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000014_0000000.cif
#  [6,3,0]
# Circumscribed sphere diameter =2.6470076750662006
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000015_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000015_0000000.cif
#  [6,3,1]
# Circumscribed sphere diameter =2.4039598864913225
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000016_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000016_0000000.cif
#  [6,3,2]
# Circumscribed sphere diameter =2.3445220020340787
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000017_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000017_0000000.cif
#  [6,4,0]
# Circumscribed sphere diameter =2.7352660378132048
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000018_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000018_0000000.cif
#  [6,4,1]
# Circumscribed sphere diameter =2.6050244467045314
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000019_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000019_0000000.cif
#  [6,4,2]
# Circumscribed sphere diameter =2.6050244467045314
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000020_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Fe_bcc_epbpyM_0000020_0000000.cif
#
#                      Mn alpha
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9011068-Mn_alpha.cif
#   xyz/cif files can't be created for Mn alpha because the interatomic distance is unknown.
#
#                      Mn beta
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod1539039-Mn_beta.cif
#   xyz/cif files can't be created for Mn beta because the interatomic distance is unknown.
#
#                       Co hcp
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008492-Co_hcp.cif
#   xyz/cif files can be created for Co hcp of Bravais lattice=hcp.
#  [3,3,0]
# Circumscribed sphere diameter =1.2833937616607445
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000001_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000001_0000000.cif
#  [3,3,1]
# Circumscribed sphere diameter =1.2833937616607445
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000002_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000002_0000000.cif
#  [3,4,0]
# Circumscribed sphere diameter =1.497292721937535
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000003_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000003_0000000.cif
#  [3,4,1]
# Circumscribed sphere diameter =1.497292721937535
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000004_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000004_0000000.cif
#  [4,3,0]
# Circumscribed sphere diameter =1.5258740436705631
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000005_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000005_0000000.cif
#  [4,3,1]
# Circumscribed sphere diameter =1.497292721937535
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000006_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000006_0000000.cif
#  [4,4,0]
# Circumscribed sphere diameter =1.7111916822143254
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000007_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000007_0000000.cif
#  [4,4,1]
# Circumscribed sphere diameter =1.7111916822143254
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000008_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000008_0000000.cif
#  [5,3,0]
# Circumscribed sphere diameter =1.8456251641869557
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000009_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000009_0000000.cif
#  [5,3,1]
# Circumscribed sphere diameter =1.7111916822143254
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000010_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000010_0000000.cif
#  [5,3,2]
# Circumscribed sphere diameter =1.7111916822143254
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000011_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000011_0000000.cif
#  [5,4,0]
# Circumscribed sphere diameter =1.930440779493785
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000012_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000012_0000000.cif
#  [5,4,1]
# Circumscribed sphere diameter =1.9250906424911163
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000013_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000013_0000000.cif
#  [5,4,2]
# Circumscribed sphere diameter =1.9250906424911163
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000014_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000014_0000000.cif
#  [6,3,0]
# Circumscribed sphere diameter =2.1734620965173774
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000015_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000015_0000000.cif
#  [6,3,1]
# Circumscribed sphere diameter =1.9738951813603771
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000016_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000016_0000000.cif
#  [6,3,2]
# Circumscribed sphere diameter =1.9250906424911165
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000017_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000017_0000000.cif
#  [6,4,0]
# Circumscribed sphere diameter =2.2459311746912816
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000018_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000018_0000000.cif
#  [6,4,1]
# Circumscribed sphere diameter =2.1389896027679067
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000019_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000019_0000000.cif
#  [6,4,2]
# Circumscribed sphere diameter =2.1389896027679067
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000020_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_hcp_epbpyM_0000020_0000000.cif
#
#                       Co fcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008466-Co_fcc.cif
#   xyz/cif files can be created for Co fcc of Bravais lattice=fcc.
#  [3,3,0]
# Circumscribed sphere diameter =1.5827544315176818
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000001_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000001_0000000.cif
#  [3,3,1]
# Circumscribed sphere diameter =1.5827544315176818
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000002_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000002_0000000.cif
#  [3,4,0]
# Circumscribed sphere diameter =1.8465468367706288
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000003_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000003_0000000.cif
#  [3,4,1]
# Circumscribed sphere diameter =1.8465468367706288
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000004_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000004_0000000.cif
#  [4,3,0]
# Circumscribed sphere diameter =1.8817949538980212
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000005_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000005_0000000.cif
#  [4,3,1]
# Circumscribed sphere diameter =1.8465468367706288
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000006_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000006_0000000.cif
#  [4,4,0]
# Circumscribed sphere diameter =2.1103392420235756
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000007_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000007_0000000.cif
#  [4,4,1]
# Circumscribed sphere diameter =2.1103392420235756
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000008_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000008_0000000.cif
#  [5,3,0]
# Circumscribed sphere diameter =2.276130284253044
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000009_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000009_0000000.cif
#  [5,3,1]
# Circumscribed sphere diameter =2.1103392420235756
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000010_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000010_0000000.cif
#  [5,3,2]
# Circumscribed sphere diameter =2.1103392420235756
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000011_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000011_0000000.cif
#  [5,4,0]
# Circumscribed sphere diameter =2.3807297415661837
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000012_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000012_0000000.cif
#  [5,4,1]
# Circumscribed sphere diameter =2.3741316472765224
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000013_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000013_0000000.cif
#  [5,4,2]
# Circumscribed sphere diameter =2.3741316472765224
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000014_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000014_0000000.cif
#  [6,3,0]
# Circumscribed sphere diameter =2.6804374992029487
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000015_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000015_0000000.cif
#  [6,3,1]
# Circumscribed sphere diameter =2.434320189936681
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000016_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000016_0000000.cif
#  [6,3,2]
# Circumscribed sphere diameter =2.374131647276523
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000017_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000017_0000000.cif
#  [6,4,0]
# Circumscribed sphere diameter =2.769810502293849
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000018_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000018_0000000.cif
#  [6,4,1]
# Circumscribed sphere diameter =2.6379240525294696
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000019_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000019_0000000.cif
#  [6,4,2]
# Circumscribed sphere diameter =2.6379240525294696
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000020_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_fcc_epbpyM_0000020_0000000.cif
#
#                     Co epsilon
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9012884-Co_epsilon.cif
#   xyz/cif files can be created for Co epsilon of Bravais lattice=hcp.
#  [3,3,0]
# Circumscribed sphere diameter =3.325354430375944
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000001_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000001_0000000.cif
#  [3,3,1]
# Circumscribed sphere diameter =3.325354430375944
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000002_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000002_0000000.cif
#  [3,4,0]
# Circumscribed sphere diameter =3.879580168771935
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000003_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000003_0000000.cif
#  [3,4,1]
# Circumscribed sphere diameter =3.879580168771935
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000004_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000004_0000000.cif
#  [4,3,0]
# Circumscribed sphere diameter =3.9536361815796774
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000005_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000005_0000000.cif
#  [4,3,1]
# Circumscribed sphere diameter =3.879580168771935
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000006_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000006_0000000.cif
#  [4,4,0]
# Circumscribed sphere diameter =4.433805907167925
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000007_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000007_0000000.cif
#  [4,4,1]
# Circumscribed sphere diameter =4.433805907167925
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000008_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000008_0000000.cif
#  [5,3,0]
# Circumscribed sphere diameter =4.782131563893941
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000009_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000009_0000000.cif
#  [5,3,1]
# Circumscribed sphere diameter =4.433805907167925
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000010_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000010_0000000.cif
#  [5,3,2]
# Circumscribed sphere diameter =4.433805907167925
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000011_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Co_epsilon_epbpyM_0000011_0000000.cif
#  [5,4,0]
#
#                       Ru hcp
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008513-Ru_hcp.cif
#   xyz/cif files can be created for Ru hcp of Bravais lattice=hcp.
#  [3,3,0]
# Circumscribed sphere diameter =1.3506074328829512
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000001_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000001_0000000.cif
#  [3,3,1]
# Circumscribed sphere diameter =1.3506074328829512
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000002_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000002_0000000.cif
#  [3,4,0]
# Circumscribed sphere diameter =1.5757086716967763
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000003_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000003_0000000.cif
#  [3,4,1]
# Circumscribed sphere diameter =1.5757086716967763
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000004_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000004_0000000.cif
#  [4,3,0]
# Circumscribed sphere diameter =1.6057868493593315
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000005_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000005_0000000.cif
#  [4,3,1]
# Circumscribed sphere diameter =1.5757086716967763
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000006_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000006_0000000.cif
#  [4,4,0]
# Circumscribed sphere diameter =1.8008099105106012
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000007_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000007_0000000.cif
#  [4,4,1]
# Circumscribed sphere diameter =1.8008099105106012
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000008_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000008_0000000.cif
#  [5,3,0]
# Circumscribed sphere diameter =1.9422839190375076
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000009_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000009_0000000.cif
#  [5,3,1]
# Circumscribed sphere diameter =1.8008099105106012
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000010_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000010_0000000.cif
#  [5,3,2]
# Circumscribed sphere diameter =1.8008099105106012
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000011_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000011_0000000.cif
#  [5,4,0]
# Circumscribed sphere diameter =2.031541482756464
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000012_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000012_0000000.cif
#  [5,4,1]
# Circumscribed sphere diameter =2.0259111493244264
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000013_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000013_0000000.cif
#  [5,4,2]
# Circumscribed sphere diameter =2.0259111493244264
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000014_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000014_0000000.cif
#  [6,3,0]
# Circumscribed sphere diameter =2.287290269236722
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000015_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000015_0000000.cif
#  [6,3,1]
# Circumscribed sphere diameter =2.0772716708762466
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000016_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000016_0000000.cif
#  [6,3,2]
# Circumscribed sphere diameter =2.025911149324427
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000017_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000017_0000000.cif
#  [6,4,0]
# Circumscribed sphere diameter =2.363554685162504
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000018_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000018_0000000.cif
#  [6,4,1]
# Circumscribed sphere diameter =2.251012388138252
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000019_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000019_0000000.cif
#  [6,4,2]
# Circumscribed sphere diameter =2.2510123881382516
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000020_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Ru_hcp_epbpyM_0000020_0000000.cif
#
#                       Pt fcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9012957-Pt_fcc.cif
#   xyz/cif files can be created for Pt fcc of Bravais lattice=fcc.
#  [3,3,0]
# Circumscribed sphere diameter =1.7468291440070285
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000001_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000001_0000000.cif
#  [3,3,1]
# Circumscribed sphere diameter =1.7468291440070285
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000002_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000002_0000000.cif
#  [3,4,0]
# Circumscribed sphere diameter =2.037967334674867
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000003_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000003_0000000.cif
#  [3,4,1]
# Circumscribed sphere diameter =2.037967334674867
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000004_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000004_0000000.cif
#  [4,3,0]
# Circumscribed sphere diameter =2.076869413887788
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000005_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000005_0000000.cif
#  [4,3,1]
# Circumscribed sphere diameter =2.037967334674867
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000006_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000006_0000000.cif
#  [4,4,0]
# Circumscribed sphere diameter =2.3291055253427047
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000007_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000007_0000000.cif
#  [4,4,1]
# Circumscribed sphere diameter =2.3291055253427047
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000008_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000008_0000000.cif
#  [5,3,0]
# Circumscribed sphere diameter =2.512083136155036
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000009_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000009_0000000.cif
#  [5,3,1]
# Circumscribed sphere diameter =2.3291055253427047
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000010_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000010_0000000.cif
#  [5,3,2]
# Circumscribed sphere diameter =2.3291055253427047
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000011_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000011_0000000.cif
#  [5,4,0]
# Circumscribed sphere diameter =2.6275257953846847
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000012_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000012_0000000.cif
#  [5,4,1]
# Circumscribed sphere diameter =2.6202437160105423
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000013_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000013_0000000.cif
#  [5,4,2]
# Circumscribed sphere diameter =2.6202437160105423
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000014_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000014_0000000.cif
#  [6,3,0]
# Circumscribed sphere diameter =2.958302468821563
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000015_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000015_0000000.cif
#  [6,3,1]
# Circumscribed sphere diameter =2.686671645928426
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000016_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000016_0000000.cif
#  [6,3,2]
# Circumscribed sphere diameter =2.620243716010543
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000017_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000017_0000000.cif
#  [6,4,0]
# Circumscribed sphere diameter =3.056940238129158
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000018_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000018_0000000.cif
#  [6,4,1]
# Circumscribed sphere diameter =2.911381906678381
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000019_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000019_0000000.cif
#  [6,4,2]
# Circumscribed sphere diameter =2.911381906678381
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000020_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Pt_fcc_epbpyM_0000020_0000000.cif
#
#                       Au fcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008463-Au_fcc.cif
#   xyz/cif files can be created for Au fcc of Bravais lattice=fcc.
#  [3,3,0]
# Circumscribed sphere diameter =1.819297705844697
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000001_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000001_0000000.cif
#  [3,3,1]
# Circumscribed sphere diameter =1.819297705844697
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000002_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000002_0000000.cif
#  [3,4,0]
# Circumscribed sphere diameter =2.122513990152146
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000003_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000003_0000000.cif
#  [3,4,1]
# Circumscribed sphere diameter =2.122513990152146
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000004_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000004_0000000.cif
#  [4,3,0]
# Circumscribed sphere diameter =2.1630299522927294
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000005_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000005_0000000.cif
#  [4,3,1]
# Circumscribed sphere diameter =2.122513990152146
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000006_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000006_0000000.cif
#  [4,4,0]
# Circumscribed sphere diameter =2.425730274459596
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000007_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000007_0000000.cif
#  [4,4,1]
# Circumscribed sphere diameter =2.425730274459596
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000008_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000008_0000000.cif
#  [5,3,0]
# Circumscribed sphere diameter =2.616298853369497
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000009_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000009_0000000.cif
#  [5,3,1]
# Circumscribed sphere diameter =2.425730274459596
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000010_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000010_0000000.cif
#  [5,3,2]
# Circumscribed sphere diameter =2.425730274459596
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000011_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000011_0000000.cif
#  [5,4,0]
# Circumscribed sphere diameter =2.7365307408518285
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000012_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000012_0000000.cif
#  [5,4,1]
# Circumscribed sphere diameter =2.728946558767045
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000013_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000013_0000000.cif
#  [5,4,2]
# Circumscribed sphere diameter =2.728946558767045
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000014_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000014_0000000.cif
#  [6,3,0]
# Circumscribed sphere diameter =3.0810299411286426
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000015_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000015_0000000.cif
#  [6,3,1]
# Circumscribed sphere diameter =2.798130302877471
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000016_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000016_0000000.cif
#  [6,3,2]
# Circumscribed sphere diameter =2.7289465587670456
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000017_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000017_0000000.cif
#  [6,4,0]
# Circumscribed sphere diameter =3.1837597747970374
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000018_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000018_0000000.cif
#  [6,4,1]
# Circumscribed sphere diameter =3.0321628430744947
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000019_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000019_0000000.cif
#  [6,4,2]
# Circumscribed sphere diameter =3.0321628430744947
#   xyz file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000020_0000000.xyz
#   cif file created:database_1_5nm/epbpyM_johnson_1_5nm/Au_fcc_epbpyM_0000020_0000000.cif
#
#                      Fe beta
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod1539039-Fe_beta.cif
#   xyz/cif files can't be created for Fe beta because the interatomic distance is unknown.
# 00:00:00 185ms
