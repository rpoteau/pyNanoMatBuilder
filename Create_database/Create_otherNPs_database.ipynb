# %% [markdown]
# # Create xyz and CIF files of other NPs of different sizes and forms from a dataset of compounds (CIF dataset)

# %% [markdown]
# ## Imports

# %%
import os
import sys
import tkinter

print(os.getcwd())
cwd0 = './styles/'
sys.path.append(cwd0)
from pathlib import Path
import numpy as np
import visualID as vID
from visualID import  fg, hl, bg

from pyNanoMatBuilder import otherNPs as oNP
from pyNanoMatBuilder import utils as pyNMBu
from pyNanoMatBuilder import data
import importlib

from ase import io
from ase.atoms import Atoms
from ase.geometry import cellpar_to_cell
from ase.spacegroup import get_spacegroup
from ase.io import read
from ase.io import write
from ase.visualize import view

from debyecalculator import DebyeCalculator
import pyNanoMatBuilder.utilsDC as pyNMBuDC
# Out:
# /home/sara/pyNanoMatBuilder

# %% [markdown]
# #### NB: the Archimedean class is instantiated by defining a compound and its interatomic distance. The function FindInterAtomicDist, which is defined in utils, calculates the interatomic distance by extracting the cell paratemers and uses well known formulas for fcc, bcc and hcp. Thus, compounds with unknown interatomic distances are not used to create Platonic NPs.

# %% [markdown]
# ## Class for others NPs ( fcc trigonal platelets)

# %% [markdown]
# <span style="color:#FF0000"> Problem : not possible to create the forms for multiple elements like TiO2 or NaCl

# %% [markdown]
# ### Definition of the 'OtherNPs_Files' class

# %%
class OtherNPs_Files :
    """
    A class for generating XYZ and CIF files of trigonal platelets from a dataset of compounds (CIF dataset). 
    This process enables the creation of a well-structured database optimized for machine learning applications, 
    ensuring consistency in format and data representation.
    """
    def __init__(self, path, cif_data,sizes,sizes2,max_size: float=50,noOutput:bool = True):
        """
        Initialize the class with CIF data and sizes.
            Args:
        path (str) : Path that will contain the created xyz files
        cif data (DataFrame):  DataFrame containing CIF files of different compounds
        sizes (array-like): Array of the lengths
        sizes2 (array-like): Array of the number of shells
        max_size (float, optional) : Maximal size for the NPs, equals to the diameter of the circumscribed sphere, equals 50 nm by default.
        noOutput (bool): If False, details of the files are printed.
            Methods:
        create_OtherNPs(noOutput, path): Generates fcc trigonal platelets nanoparticles and saves their files.
        """
        self.cif_data = cif_data  # DataFrame containing CIF
        self.loaded_cifs = {}  # Dictionary to store loaded CIF files
        self.sizes= sizes # List of sizes 
        self.sizes2= sizes2
        form='fcctpt'
        
        self.create_OtherNPs(noOutput,max_size,path,form) # Call method to generate other nanoparticles


    def create_OtherNPs(self,noOutput,max_size,path,form):
        """
        Genenrate fcc trigonal platelets NPs and their files from cif data.
        Args:
            noOutput (bool): If False, prints details about the process.
            path (str): Path where xyz/cif files will be created.
 
        """
      
        for cif_name, cif_file in self.cif_data['cif file'].items():
            
            # Load cif informations
            element=cif_name.split()[0] # Extract chemical element from CIF name
            
            if not (element=='TiO2' or element=='NaCl'): # Skip TiO2 and NaCl since they are not processed
                self.cif_name=cif_name
                
                # Extract the structure name for the name of the files, for example 'Rutile' or 'Anatase' or 'Alpha'
                if len(self.cif_name.split())==2 : 
                    structure=self.cif_name.split()[1]
                else : 
                    structure=None
                if not noOutput :
                    print(f'\n\033[1m{cif_name.center(50)}\033[0m\n')
                cif_info = pyNMBu.load_cif(self,cif_file,noOutput)
                    
                # Determine forms based on crystal type
                if self.crystal_type=='fcc' :
                    dist= pyNMBu.FindInterAtomicDist(self)# Extract the interatomic distance
                    index=0 
                    if not noOutput :
                        print(f" {bg.LIGHTGREENB} xyz/cif files can be created for {self.cif_name} of Bravais lattice={self.crystal_type} for the form {form}. \033[0m ")
                        # Create instances for each form and size
                    for i in self.sizes :
                        for y in self.sizes2:
                            index += 1 
                            if not noOutput :
                                print(f'{bg.LIGHTBLUEB} Sizes [{i},{y}]')
                            TestNP =oNP.fcctpt(
                                element=element,
                                Rnn=dist,
                                nLayerTd=i,
                                nLayer = y, #number of layers per pyramid -> total number of layers = nLayer*2 + twinning plane
                                postAnalyzis=True,
                                aseView=False,
                                thresholdCoreSurface=1,
                                skipSymmetryAnalyzis=True,
                                noOutput= True
                            )
    
                            circumsphere_diameter=TestNP.radiusCircumscribedSphere*2*0.1 # Setting a maximal size of NPs : circumscribed sphere diameter
                            if circumsphere_diameter<max_size :
                                if not noOutput :
                                    print(f'{bg.LIGHTBLUEB}Circumscribed sphere diameter ={circumsphere_diameter}\033[0m')
                                pyNMBu.writexyz_generalized_otherNPs(self,structure,path,TestNP,index,noOutput) 
                            else :
                                break


                else : 
                    if not noOutput :
                        print(f" {bg.LIGHTREDB} xyz/cif files can't be created for {self.cif_name} because the crystal type isn't fcc.\033[0m  ")   
                    pass
         
            else : 
                pass

# %%
OtherNPs_Files?
# Out:
# Init signature:
# OtherNPs_Files(
#     path,
#     cif_data,
#     sizes,
#     sizes2,
#     max_size: float = 50,
#     noOutput: bool = True,
# )
# Docstring:
# A class for generating XYZ and CIF files of trigonal platelets from a dataset of compounds (CIF dataset).
# This process enables the creation of a well-structured database optimized for machine learning applications,
# ensuring consistency in format and data representation.
# Init docstring:
# Initialize the class with CIF data and sizes.
#     Args:
# path (str) : Path that will contain the created xyz files
# cif data (DataFrame):  DataFrame containing CIF files of different compounds
# sizes (array-like): Array of the lengths
# sizes2 (array-like): Array of the number of shells
# max_size (float, optional) : Maximal size for the NPs, equals to the diameter of the circumscribed sphere, equals 50 nm by default.
# noOutput (bool): If False, details of the files are printed.
#     Methods:
# create_OtherNPs(noOutput, path): Generates fcc trigonal platelets nanoparticles and saves their files.
# Type:           type
# Subclasses:

# %% [markdown]
# ### Example of use of the OtherNPs_Files class

# %% [markdown]
# If noOutput=False :
#  - <span style="color:#008000"> in green : the allowed shapes created (fcc) </span>
#  - <span style="color:#FF0000">in red : the shapes that are not created (not fcc)</span>

# %%
t = pyNMBu.timer()
t.chrono_start()

# Path where the files are created
path='database_1_5nm/otherNPs_1_5nm'

# Sizes of the NPs
sizes=np.arange(5,25,1) # Control the sizes by nShells= the number of bonds per edges : here 1 to 25 bonds (step of 1)
sizes2=np.arange(1,3,1)
# Possiblity to define a maximal size: max_size (a circumsphere diameter). If max_size isn't defined, the NPs will have the maximum number of bonds defined, here 25.
class_test=OtherNPs_Files(path,cif_data=data.pyNMBcif.CIFdf,sizes=sizes,sizes2=sizes2,max_size=5,noOutput= False) # Ex: the maximal size is a circumsphere diameter of 5 nm.



print(t.chrono_stop(hdelay=True))
# Out:
#                       Fe bcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod5000217-Fe_bcc.cif
#   xyz/cif files can't be created for Fe bcc because the crystal type isn't fcc.
#
#                      Mn alpha
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9011068-Mn_alpha.cif
#   xyz/cif files can't be created for Mn alpha because the crystal type isn't fcc.
#
#                      Mn beta
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod1539039-Mn_beta.cif
#   xyz/cif files can't be created for Mn beta because the crystal type isn't fcc.
#
#                       Co hcp
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008492-Co_hcp.cif
#   xyz/cif files can't be created for Co hcp because the crystal type isn't fcc.
#
#                       Co fcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008466-Co_fcc.cif
#   xyz/cif files can be created for Co fcc of Bravais lattice=fcc for the form fcctpt.
#  Sizes [5,1]
# Circumscribed sphere diameter =1.7381579214789438
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000001_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000001_0000000.cif
#  Sizes [5,2]
# Circumscribed sphere diameter =1.7381579214789438
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000002_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000002_0000000.cif
#  Sizes [6,1]
# Circumscribed sphere diameter =2.027850908392101
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000003_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000003_0000000.cif
#  Sizes [6,2]
# Circumscribed sphere diameter =2.027850908392101
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000004_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000004_0000000.cif
#  Sizes [7,1]
# Circumscribed sphere diameter =2.3175438953052576
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000005_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000005_0000000.cif
#  Sizes [7,2]
# Circumscribed sphere diameter =2.3175438953052576
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000006_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000006_0000000.cif
#  Sizes [8,1]
# /home/sara/Python3/Debye_calc/lib/python3.11/site-packages/ase/io/cif.py:408: UserWarning: crystal system 'cubic' is not interpreted for space group Spacegroup(229, setting=1). This may result in wrong setting!
#   warnings.warn(
# Circumscribed sphere diameter =2.607236882218415
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000007_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000007_0000000.cif
#  Sizes [8,2]
# Circumscribed sphere diameter =2.607236882218415
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000008_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000008_0000000.cif
#  Sizes [9,1]
# Circumscribed sphere diameter =2.8969298691315726
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000009_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000009_0000000.cif
#  Sizes [9,2]
# Circumscribed sphere diameter =2.8969298691315726
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000010_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000010_0000000.cif
#  Sizes [10,1]
# Circumscribed sphere diameter =3.18662285604473
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000011_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000011_0000000.cif
#  Sizes [10,2]
# Circumscribed sphere diameter =3.18662285604473
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000012_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000012_0000000.cif
#  Sizes [11,1]
# Circumscribed sphere diameter =3.4763158429578866
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000013_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000013_0000000.cif
#  Sizes [11,2]
# Circumscribed sphere diameter =3.4763158429578875
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000014_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000014_0000000.cif
#  Sizes [12,1]
# Circumscribed sphere diameter =3.7660088298710437
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000015_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000015_0000000.cif
#  Sizes [12,2]
# Circumscribed sphere diameter =3.7660088298710437
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000016_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000016_0000000.cif
#  Sizes [13,1]
# Circumscribed sphere diameter =4.055701816784203
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000017_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000017_0000000.cif
#  Sizes [13,2]
# Circumscribed sphere diameter =4.055701816784202
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000018_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000018_0000000.cif
#  Sizes [14,1]
# Circumscribed sphere diameter =4.345394803697359
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000019_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000019_0000000.cif
#  Sizes [14,2]
# Circumscribed sphere diameter =4.345394803697359
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000020_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000020_0000000.cif
#  Sizes [15,1]
# Circumscribed sphere diameter =4.635087790610515
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000021_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000021_0000000.cif
#  Sizes [15,2]
# Circumscribed sphere diameter =4.635087790610515
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000022_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000022_0000000.cif
#  Sizes [16,1]
# Circumscribed sphere diameter =4.924780777523673
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000023_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000023_0000000.cif
#  Sizes [16,2]
# Circumscribed sphere diameter =4.924780777523672
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000024_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Co_fcc_fcctpt_0000024_0000000.cif
#  Sizes [17,1]
#  Sizes [18,1]
#  Sizes [19,1]
#  Sizes [20,1]
#  Sizes [21,1]
#  Sizes [22,1]
#  Sizes [23,1]
#  Sizes [24,1]
#
#                     Co epsilon
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9012884-Co_epsilon.cif
#   xyz/cif files can't be created for Co epsilon because the crystal type isn't fcc.
#
#                       Ru hcp
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008513-Ru_hcp.cif
#   xyz/cif files can't be created for Ru hcp because the crystal type isn't fcc.
#
#                       Pt fcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9012957-Pt_fcc.cif
#   xyz/cif files can be created for Pt fcc of Bravais lattice=fcc for the form fcctpt.
#  Sizes [5,1]
# Circumscribed sphere diameter =1.9183423869580736
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000001_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000001_0000000.cif
#  Sizes [5,2]
# Circumscribed sphere diameter =1.9183423869580736
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000002_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000002_0000000.cif
#  Sizes [6,1]
# Circumscribed sphere diameter =2.238066118117753
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000003_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000003_0000000.cif
#  Sizes [6,2]
# Circumscribed sphere diameter =2.238066118117753
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000004_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000004_0000000.cif
#  Sizes [7,1]
# Circumscribed sphere diameter =2.557789849277432
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000005_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000005_0000000.cif
#  Sizes [7,2]
# Circumscribed sphere diameter =2.557789849277432
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000006_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000006_0000000.cif
#  Sizes [8,1]
# Circumscribed sphere diameter =2.8775135804371104
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000007_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000007_0000000.cif
#  Sizes [8,2]
# Circumscribed sphere diameter =2.8775135804371104
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000008_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000008_0000000.cif
#  Sizes [9,1]
# Circumscribed sphere diameter =3.197237311596789
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000009_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000009_0000000.cif
#  Sizes [9,2]
# Circumscribed sphere diameter =3.197237311596789
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000010_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000010_0000000.cif
#  Sizes [10,1]
# Circumscribed sphere diameter =3.516961042756468
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000011_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000011_0000000.cif
#  Sizes [10,2]
# Circumscribed sphere diameter =3.516961042756468
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000012_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000012_0000000.cif
#  Sizes [11,1]
# Circumscribed sphere diameter =3.836684773916147
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000013_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000013_0000000.cif
#  Sizes [11,2]
# Circumscribed sphere diameter =3.836684773916148
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000014_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000014_0000000.cif
#  Sizes [12,1]
# Circumscribed sphere diameter =4.156408505075826
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000015_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000015_0000000.cif
#  Sizes [12,2]
# Circumscribed sphere diameter =4.156408505075826
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000016_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000016_0000000.cif
#  Sizes [13,1]
# Circumscribed sphere diameter =4.4761322362355065
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000017_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000017_0000000.cif
#  Sizes [13,2]
# Circumscribed sphere diameter =4.476132236235506
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000018_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000018_0000000.cif
#  Sizes [14,1]
# Circumscribed sphere diameter =4.795855967395185
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000019_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000019_0000000.cif
#  Sizes [14,2]
# Circumscribed sphere diameter =4.795855967395185
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000020_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Pt_fcc_fcctpt_0000020_0000000.cif
#  Sizes [15,1]
#  Sizes [16,1]
#  Sizes [17,1]
#  Sizes [18,1]
#  Sizes [19,1]
#  Sizes [20,1]
#  Sizes [21,1]
#  Sizes [22,1]
#  Sizes [23,1]
#  Sizes [24,1]
#
#                       Au fcc
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod9008463-Au_fcc.cif
#   xyz/cif files can be created for Au fcc of Bravais lattice=fcc for the form fcctpt.
#  Sizes [5,1]
# Circumscribed sphere diameter =1.9979263087010992
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000001_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000001_0000000.cif
#  Sizes [5,2]
# Circumscribed sphere diameter =1.9979263087010992
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000002_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000002_0000000.cif
#  Sizes [6,1]
# Circumscribed sphere diameter =2.3309140268179487
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000003_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000003_0000000.cif
#  Sizes [6,2]
# Circumscribed sphere diameter =2.3309140268179487
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000004_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000004_0000000.cif
#  Sizes [7,1]
# Circumscribed sphere diameter =2.6639017449347993
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000005_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000005_0000000.cif
#  Sizes [7,2]
# Circumscribed sphere diameter =2.6639017449347993
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000006_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000006_0000000.cif
#  Sizes [8,1]
# Circumscribed sphere diameter =2.996889463051649
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000007_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000007_0000000.cif
#  Sizes [8,2]
# Circumscribed sphere diameter =2.996889463051649
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000008_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000008_0000000.cif
#  Sizes [9,1]
# Circumscribed sphere diameter =3.3298771811684995
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000009_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000009_0000000.cif
#  Sizes [9,2]
# Circumscribed sphere diameter =3.3298771811684995
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000010_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000010_0000000.cif
#  Sizes [10,1]
# Circumscribed sphere diameter =3.662864899285348
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000011_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000011_0000000.cif
#  Sizes [10,2]
# Circumscribed sphere diameter =3.662864899285348
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000012_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000012_0000000.cif
#  Sizes [11,1]
# Circumscribed sphere diameter =3.9958526174021984
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000013_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000013_0000000.cif
#  Sizes [11,2]
# Circumscribed sphere diameter =3.9958526174021984
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000014_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000014_0000000.cif
#  Sizes [12,1]
# Circumscribed sphere diameter =4.328840335519049
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000015_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000015_0000000.cif
#  Sizes [12,2]
# Circumscribed sphere diameter =4.328840335519049
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000016_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000016_0000000.cif
#  Sizes [13,1]
# Circumscribed sphere diameter =4.661828053635897
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000017_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000017_0000000.cif
#  Sizes [13,2]
# Circumscribed sphere diameter =4.661828053635897
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000018_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000018_0000000.cif
#  Sizes [14,1]
# Circumscribed sphere diameter =4.994815771752748
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000019_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000019_0000000.cif
#  Sizes [14,2]
# Circumscribed sphere diameter =4.994815771752749
#   xyz file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000020_0000000.xyz
#   cif file created:database_1_5nm/otherNPs_1_5nm/Au_fcc_fcctpt_0000020_0000000.cif
#  Sizes [15,1]
#  Sizes [16,1]
#  Sizes [17,1]
#  Sizes [18,1]
#  Sizes [19,1]
#  Sizes [20,1]
#  Sizes [21,1]
#  Sizes [22,1]
#  Sizes [23,1]
#  Sizes [24,1]
#
#                      Fe beta
#
# Absolute path to CIF: /home/sara/pyNanoMatBuilder/cif_database/cod1539039-Fe_beta.cif
#   xyz/cif files can't be created for Fe beta because the crystal type isn't fcc.
# 00:00:00 178ms
