# %%
print(-98.415/-54.6753348)
9/5
# Out:
# 1.7999889778452716
# 1.8

# %%
-98.415/-57.40875
# Out:
# 1.7142857142857144

# %%
12/7
# Out:
# 1.7142857142857142

# %%
import numpy as np
np.sqrt(6)*2/9
# Out:
# 0.5443310539518174

# %%
print(1.8371173070873836*54.6753348)
# Out:
# 100.44500383187712

# %%
1/0.5773502691896258
# Out:
# 1.732050807568877

# %%
np.sqrt(3)
# Out:
# 1.7320508075688772

# %%
print(-9.92043346**2)
# Out:
# -98.41500003428757

# %%
print(np.sqrt(54.6753348))
# Out:
# 7.394277165484128

# %%
print(1/(-9.92043346/7.394277165484128))
# Out:
# -0.7453582744442024
