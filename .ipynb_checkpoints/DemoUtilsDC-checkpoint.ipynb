# %% [markdown]
# # <font color='green'> DebyeCalculator added utilities : examples</font>

# %% [markdown]
# ## In this notebook, we will demonstrate how to use the added utilities *(from utilsDC in pyNanoMatBuilder*) to ease Debye Calculator's use.

# %% [markdown]
# ### Added utilities :
# - plotting I(q),F(q),S(q) and G(r) of multiples nanoparticles
# - create multiple csv files containing scattering data calculated from xyz/cif files/ASE objects

# %%
import debyecalculator
print(debyecalculator.__file__)
# Out:
# /home/sara/Python3/Debye_calc/lib/python3.11/site-packages/debyecalculator/__init__.py

# %%
import sys
print(sys.executable)# Afficher les fichiers ajoutés au bouton de téléchargement
# Out:
# /home/sara/Python3/Debye_calc/bin/python

# %%
#imports
import os
import pyNanoMatBuilder
from debyecalculator import DebyeCalculator
import pyNanoMatBuilder.utilsDC as pyNMBuDC


print(os.getcwd()) #path
# Out:
# /home/sara/pyNanoMatBuilder

# %% [markdown]
# ## 1. Plotting loglog(I(q), S(q), F(q), G(r)) using an atomic structure source in XYZ/CIF format, ASE Atoms object, or as a tuple of (atomic_identities, atomic_positions).

# %% [markdown]
# ### I=f(q) using cif file

# %%
from debyecalculator import DebyeCalculator


path = os.path.join("coords", 'AuParallepiped.cif')
#path = os.path.join(
radii = [5.0]

# path_to_xyz_file = "debyecalculator/data/AntiFluorite_Co2O.cif"
calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)
q, iq = calc.iq(path, radii)

#q, iq = calc.iq('/home/sara/pyNanoMatBuilder/coords/cubo.xyz')
pyNMBuDC.plot_loglogiq( q, iq, figsize=(5,6),color='green')
# Out:
# /tmp/ipykernel_555362/3296841170.py:9: UserWarning: Warning: Your system might have a CUDA-enabled GPU, but CUDA is not available. Computations will run on the CPU instead. For optimal performance, please install Pytorch with CUDA support. If you do not have a CUDA-enabled GPU, you can surpress this warning by specifying the 'device' argument as 'cpu'
#   calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)

# %% [markdown]
# #### test cif sans np sphérique et radii

# %%
from debyecalculator import DebyeCalculator

path = os.path.join("coords", 'trTd.xyz')
#path = os.path.join(
#radii = [5.0]

# path_to_xyz_file = "debyecalculator/data/AntiFluorite_Co2O.cif"
calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)
q, iq = calc.iq(path)

#q, iq = calc.iq('/home/sara/pyNanoMatBuilder/coords/cubo.xyz')
pyNMBuDC.plot_loglogiq( q, iq, figsize=(5,6),color='green')

# %% [markdown]
# ### I=f(q) using xyz file

# %%
path = os.path.join("coords", "cubo.xyz")
print(path)  

calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)
q, iq = calc.iq(path)

#q, iq = calc.iq('/home/sara/pyNanoMatBuilder/coords/cubo.xyz')
pyNMBuDC.plot_loglogiq(q, iq, figsize=(5,6),color='green')
# Out:
# coords/cubo.xyz
# /tmp/ipykernel_150278/1238776453.py:4: UserWarning: Warning: Your system might have a CUDA-enabled GPU, but CUDA is not available. Computations will run on the CPU instead. For optimal performance, please install Pytorch with CUDA support. If you do not have a CUDA-enabled GPU, you can surpress this warning by specifying the 'device' argument as 'cpu'
#   calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)

# %% [markdown]
# ### Plotting S=f(q)

# %%
path = os.path.join("coords", 'SphericalAuNP.xyz')
print(path)  
     
calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)
q, sq = calc.sq(path)
 

pyNMBuDC.plot_sq(q, sq, figsize=(6,4),color='red')
# Out:
# coords/SphericalAuNP.xyz
# /tmp/ipykernel_150278/255082502.py:4: UserWarning: Warning: Your system might have a CUDA-enabled GPU, but CUDA is not available. Computations will run on the CPU instead. For optimal performance, please install Pytorch with CUDA support. If you do not have a CUDA-enabled GPU, you can surpress this warning by specifying the 'device' argument as 'cpu'
#   calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)

# %% [markdown]
# ### Plotting F=f(q)

# %%
path = os.path.join("coords", "RuWire.xyz")
print(path)  

calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)
q, fq = calc.fq(path)


pyNMBuDC.plot_fq(q, fq, figsize=(6,4),color='blue')
# Out:
# coords/RuWire.xyz
# /tmp/ipykernel_150278/631926799.py:4: UserWarning: Warning: Your system might have a CUDA-enabled GPU, but CUDA is not available. Computations will run on the CPU instead. For optimal performance, please install Pytorch with CUDA support. If you do not have a CUDA-enabled GPU, you can surpress this warning by specifying the 'device' argument as 'cpu'
#   calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)

# %% [markdown]
# ### Plotting G=f(r)

# %%
path = os.path.join("coords", "trTd.xyz")
print(path)  

calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)
r, gr = calc.gr(path)

# Maintenant pour plot 
pyNMBuDC.plot_gr(r, gr, figsize=(6,4),color='purple')
# Out:
# coords/trTd.xyz
# /tmp/ipykernel_150278/2867518572.py:4: UserWarning: Warning: Your system might have a CUDA-enabled GPU, but CUDA is not available. Computations will run on the CPU instead. For optimal performance, please install Pytorch with CUDA support. If you do not have a CUDA-enabled GPU, you can surpress this warning by specifying the 'device' argument as 'cpu'
#   calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)

# %% [markdown]
# ## 2. Create multiple csv files containing scattering data + metadata from cif/xyz pyNanomatBuilder files

# %% [markdown]
# The fuction `create_iqfiles_from_xyzfiles()`, as well as the fuctions for S(q),F(q) and G(r), takes as input:
# - an instance of DebyeCalculator class
# - path of the xyz/cif files
# - path of the final csv files\
#  <font color='green'> Note : the xyz files contain a dictionnary of meta data : composition, cristalline structure, shape, size.

# %% [markdown]
# ### CSV files containing (q,I)

# %%
path_of_coords="Files_DC_demo/xyz_files_DC_demo"
path_of_csvfiles="Files_DC_demo/csv_files_DC_demo"
calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)
pyNMBuDC.create_iqfiles_from_xyzfiles(calc,path_of_coords,path_of_csvfiles,noOutput=False)
# Out:
# file used : Au_fcc_fccCubo_0000001_0000000.xyz
# q 380 iq 380
#
#  New file created:Files_DC_demo/csv_files_DC_demo/Au_fcc_fccCubo_0000001_0000000_DC_iq.csv
#
# file used : Au_fcc_ellipsoid_0000001_0000000.xyz
# q 380 iq 380
#
#  New file created:Files_DC_demo/csv_files_DC_demo/Au_fcc_ellipsoid_0000001_0000000_DC_iq.csv
#
# file used : Au_fcc_epbpyM_0000001_0000000.xyz
# q 380 iq 380
#
#  New file created:Files_DC_demo/csv_files_DC_demo/Au_fcc_epbpyM_0000001_0000000_DC_iq.csv
#
# file used : Co_hcp_wire_4_0000001_0000000.xyz
# q 380 iq 380
#
#  New file created:Files_DC_demo/csv_files_DC_demo/Co_hcp_wire_4_0000001_0000000_DC_iq.csv
#
# file used : Pt_fcc_fcctpt_0000001_0000000.xyz
# q 380 iq 380
#
#  New file created:Files_DC_demo/csv_files_DC_demo/Pt_fcc_fcctpt_0000001_0000000_DC_iq.csv
#
# Total of csv files created 5
# /tmp/ipykernel_555362/2778326542.py:3: UserWarning: Warning: Your system might have a CUDA-enabled GPU, but CUDA is not available. Computations will run on the CPU instead. For optimal performance, please install Pytorch with CUDA support. If you do not have a CUDA-enabled GPU, you can surpress this warning by specifying the 'device' argument as 'cpu'
#   calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)

# %% [markdown]
# ### CSV files containing (q,S)

# %%
path_of_coords="Files_DC_demo/xyz_files_DC_demo"
path_of_csvfiles="Files_DC_demo/csv_files_DC_demo"                
calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)   
radii=[5.0]
pyNMBuDC.create_sqfiles_from_xyzfiles(calc,path_of_coords,path_of_csvfiles,radii)
# Out:
# file used : Au_fcc_fccCubo_0000001_0000000.xyz
# q 380 sq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Au_fcc_fccCubo_0000001_0000000_DC_sq.csv
# file used : Au_fcc_ellipsoid_0000001_0000000.xyz
# q 380 sq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Au_fcc_ellipsoid_0000001_0000000_DC_sq.csv
# file used : Au_fcc_epbpyM_0000001_0000000.xyz
# q 380 sq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Au_fcc_epbpyM_0000001_0000000_DC_sq.csv
# file used : Co_hcp_wire_4_0000001_0000000.xyz
# q 380 sq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Co_hcp_wire_4_0000001_0000000_DC_sq.csv
# file used : Pt_fcc_fcctpt_0000001_0000000.xyz
# q 380 sq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Pt_fcc_fcctpt_0000001_0000000_DC_sq.csv
# /tmp/ipykernel_555362/685454007.py:3: UserWarning: Warning: Your system might have a CUDA-enabled GPU, but CUDA is not available. Computations will run on the CPU instead. For optimal performance, please install Pytorch with CUDA support. If you do not have a CUDA-enabled GPU, you can surpress this warning by specifying the 'device' argument as 'cpu'
#   calc = DebyeCalculator(qmin=1.0, qmax=20.0, qstep=0.05, qdamp=0.0, biso=0.0)

# %% [markdown]
# ### CSV files containing (q,F)

# %%
pyNMBuDC.create_fqfiles_from_xyzfiles(calc,path_of_coords,path_of_csvfiles)
# Out:
# file used : Au_fcc_fccCubo_0000001_0000000.xyz
# q 380 fq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Au_fcc_fccCubo_0000001_0000000_DC_fq.csv
# file used : Au_fcc_ellipsoid_0000001_0000000.xyz
# q 380 fq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Au_fcc_ellipsoid_0000001_0000000_DC_fq.csv
# file used : Au_fcc_epbpyM_0000001_0000000.xyz
# q 380 fq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Au_fcc_epbpyM_0000001_0000000_DC_fq.csv
# file used : Co_hcp_wire_4_0000001_0000000.xyz
# q 380 fq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Co_hcp_wire_4_0000001_0000000_DC_fq.csv
# file used : Pt_fcc_fcctpt_0000001_0000000.xyz
# q 380 fq 380
# New file created: Files_DC_demo/csv_files_DC_demo/Pt_fcc_fcctpt_0000001_0000000_DC_fq.csv

# %% [markdown]
# ### CSV files containing (r,G)

# %%
pyNMBuDC.create_grfiles_from_xyzfiles(calc,path_of_coords,path_of_csvfiles)
# Out:
# file used : Au_fcc_fccCubo_0000001_0000000.xyz
# r 2000 gr 2000
# New file created: Files_DC_demo/csv_files_DC_demo/Au_fcc_fccCubo_0000001_0000000_DC_gr.csv
# file used : Au_fcc_ellipsoid_0000001_0000000.xyz
# r 2000 gr 2000
# New file created: Files_DC_demo/csv_files_DC_demo/Au_fcc_ellipsoid_0000001_0000000_DC_gr.csv
# file used : Au_fcc_epbpyM_0000001_0000000.xyz
# r 2000 gr 2000
# New file created: Files_DC_demo/csv_files_DC_demo/Au_fcc_epbpyM_0000001_0000000_DC_gr.csv
# file used : Co_hcp_wire_4_0000001_0000000.xyz
# r 2000 gr 2000
# New file created: Files_DC_demo/csv_files_DC_demo/Co_hcp_wire_4_0000001_0000000_DC_gr.csv
# file used : Pt_fcc_fcctpt_0000001_0000000.xyz
# r 2000 gr 2000
# New file created: Files_DC_demo/csv_files_DC_demo/Pt_fcc_fcctpt_0000001_0000000_DC_gr.csv

# %% [markdown]
# ## à ajouter :
# - pouvoir tracer plusieurs graph à la fois
# - pour la fonction qui trace les fichiers : ajouter plusieurs entrées possibles : objet ASE, chemin, fichier
# - attention : fichier cif ne fonctionne pas sans "radii" = uniquement pour np sphériques?
# - enlever " .ipynb_checkpoints" quand on vérifie le type de fichier
# - filtre : attention je l'avais ajouté dans debye calculator (parse elements) mais à ajouter ailleurs

# %%
calc = DebyeCalculator(qmin=0.5, qmax=16.6, qstep=0.01, qdamp=0.0, biso=0.0)
# Out:
# /tmp/ipykernel_150596/421552557.py:1: UserWarning: Warning: Your system might have a CUDA-enabled GPU, but CUDA is not available. Computations will run on the CPU instead. For optimal performance, please install Pytorch with CUDA support. If you do not have a CUDA-enabled GPU, you can surpress this warning by specifying the 'device' argument as 'cpu'
#   calc = DebyeCalculator(qmin=0.5, qmax=16.6, qstep=0.01, qdamp=0.0, biso=0.0)

# %% [markdown]
# ### RuWire 12x4 nm

# %%
path1= '/home/sara/Téléchargements/wires_presentation/RuWire/ruwires/RuWire12x4.xyz'
 
q1, iq1 = calc.iq(path1)

# %%
pyNMBuDC.plot_loglogiq(q1, iq1, figsize=(15,7),color='green')

# %%
r1, gr1 = calc.gr(path1)

# %%
pyNMBuDC.plot_gr(r1, gr1, figsize=(15,7),color='g')

# %% [markdown]
# ### RuWire 9x3 nm

# %%
path2= '/home/sara/Téléchargements/wires_presentation/RuWire/ruwires/RuWire9x3.xyz'
q2, iq2 = calc.iq(path2)

# %%
pyNMBuDC.plot_loglogiq( q2, iq2, figsize=(15,7),color='b')

# %%
r2, gr2 = calc.gr(path2)

# %%
pyNMBuDC.plot_gr(r2, gr2, figsize=(15,7),color='b')
